# %% [markdown]
# <a href="https://colab.research.google.com/github/IagoAlmeida-ias/Python-para-Data-Science/blob/main/01_AquisicaoDeDado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Carregando Dados com a Bíblioteca Pandas
# O pandas é a pricipal bíbliotca para manipulação, anáse e visualização de dados.

# %%
import pandas as pd

# %%
# Arquivo CSV - Vírgula
df = pd.read_csv('base_vendas.csv')

# %%
df
# notas "CRISP-DM" -----> Soluções Analiticas
# Pesquisar ↑↑↑↑↑ depois
# Out:
#       matricula_funcionario Nome Funcionario     Cargo codigo_loja  \
# 0                 123456111       José Maria  Vendedor       CL001
# 1                 123456111       José Maria  Vendedor       CL001
# 2                 123456111       José Maria  Vendedor       CL001
# 3                 123456111       José Maria  Vendedor       CL001
# 4                 123456111       José Maria  Vendedor       CL001
# ...                     ...              ...       ...         ...
# 2995              123457113      Victor Hugo  Vendedor       CL004
# 2996              123457113      Victor Hugo  Vendedor       CL004
# 2997              123457113      Victor Hugo  Vendedor       CL004
# 2998              123457113      Victor Hugo  Vendedor       CL004
# 2999              123457113      Victor Hugo  Vendedor       CL004
#
#         nome_loja  codigo_produto    descricao_produto         Categoria  \
# 0     Loja Matriz           10013                Fogão  Eletrodomésticos
# ...

# %%
df = pd.read_csv('base_vendas_ponto_virgula.csv', delimiter=';')    # sep=',' tambem faz o mesmo (delimitar o separador)

# %%
df.head()   # Colocar no () quantas linhas vc quer
# Out:
#    matricula_funcionario Nome Funcionario     Cargo codigo_loja    nome_loja  \
# 0              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 1              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 2              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 3              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 4              123456111       José Maria  Vendedor       CL001  Loja Matriz
#
#    codigo_produto    descricao_produto         Categoria preco_custo  \
# 0           10013                Fogão  Eletrodomésticos       210,9
# 1           10018              Colchão              Casa       109,9
# 2           10014            Geladeira  Eletrodomésticos       699,9
# 3           10001           Smartphone       Eletrônicos       899,9
# 4           10004  Máquina Lavar Roupa  Eletrodomésticos        1099
#
#   valor_unitario  quantidade comissao          dt_venda        dt_entrega
# ...

# %%
df.tail()    # Colocar no () quantas linhas vc quer
# Out:
#     matricula_funcionario Nome Funcionario     Cargo codigo_loja    nome_loja  \
# 95              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 96              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 97              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 98              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 99              123456111       José Maria  Vendedor       CL001  Loja Matriz
#
#     codigo_produto         descricao_produto    Categoria preco_custo  \
# 95           10017                  Cama Box         Casa      1189,9
# 96           10005                  Notebook  Eletrônicos      2299,9
# 97           10020                Impressora  Eletrônicos       329,9
# 98           10012  Processador de alimentos      Cozinha         110
# 99           10018                   Colchão         Casa       109,9
#
#    valor_unitario  quantidade comissao          dt_venda        dt_entrega
# ...

# %%
df.shape
# Out:
# (100, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   matricula_funcionario  100 non-null    int64
#  1   Nome Funcionario       100 non-null    object
#  2   Cargo                  100 non-null    object
#  3   codigo_loja            100 non-null    object
#  4   nome_loja              100 non-null    object
#  5   codigo_produto         100 non-null    int64
#  6   descricao_produto      100 non-null    object
#  7   Categoria              100 non-null    object
#  8   preco_custo            100 non-null    object
#  9   valor_unitario         100 non-null    object
#  10  quantidade             100 non-null    int64
#  11  comissao               9 non-null      object
#  12  dt_venda               100 non-null    object
#  13  dt_entrega             100 non-null    object
# dtypes: int64(3), object(11)
# ...

# %%
df = pd.read_excel('Vendas.xlsx')     # carrega a primeira que ver

# %%
df.tail()
# Out:
#     matricula_funcionario Nome Funcionario
# 8               123456777    Marcos Coelho
# 9               123456888     Rita Sampaio
# 10              123457112   Mário Henrique
# 11              123457111      Pamela Lima
# 12              123457113      Victor Hugo

# %%
df_vendas = pd.read_excel('Vendas.xlsx', sheet_name='base_vendas')    # Sheet_name para carregar a qual vc qr

# %%
df_vendas.head()
# Out:
#    matricula_funcionario Nome Funcionario     Cargo codigo_loja    nome_loja  \
# 0              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 1              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 2              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 3              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 4              123456111       José Maria  Vendedor       CL001  Loja Matriz
#
#    codigo_produto    descricao_produto         Categoria  preco_custo  \
# 0           10013                Fogão  Eletrodomésticos        210.9
# 1           10018              Colchão              Casa        109.9
# 2           10014            Geladeira  Eletrodomésticos        699.9
# 3           10001           Smartphone       Eletrônicos        899.9
# 4           10004  Máquina Lavar Roupa  Eletrodomésticos       1099.0
#
#    valor_unitario  quantidade  comissao            dt_venda  \
# ...

# %%
# Aruqivo HTML contém a tag <table><\table>

lista_tabela = pd.read_html('base_vendas.html')

# %%
type(lista_tabela)
len(lista_tabela)
# Out:
# 1

# %%
# Buscando o prmeiro DataFrame do Arquivo HTML

df = lista_tabela[0]

# %%
df_q = pd.read_hdf('base_vendas.h5')

# %%
df_q.head()
# Out:
#    matricula_funcionario Nome Funcionario     Cargo codigo_loja    nome_loja  \
# 0              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 1              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 2              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 3              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 4              123456111       José Maria  Vendedor       CL001  Loja Matriz
#
#    codigo_produto    descricao_produto         Categoria preco_custo  \
# 0           10013                Fogão  Eletrodomésticos       210,9
# 1           10018              Colchão              Casa       109,9
# 2           10014            Geladeira  Eletrodomésticos       699,9
# 3           10001           Smartphone       Eletrônicos       899,9
# 4           10004  Máquina Lavar Roupa  Eletrodomésticos        1099
#
#   valor_unitario  quantidade comissao          dt_venda        dt_entrega
# ...

# %%
df = pd.read_xml('base_vendas.xml')

# %%
df.head()
# Out:
#    index  matricula_funcionario nome_funcionario     cargo codigo_loja  \
# 0      0              123456111       José Maria  Vendedor       CL001
# 1      1              123456111       José Maria  Vendedor       CL001
# 2      2              123456111       José Maria  Vendedor       CL001
# 3      3              123456111       José Maria  Vendedor       CL001
# 4      4              123456111       José Maria  Vendedor       CL001
#
#      nome_loja  codigo_produto    descricao_produto         categoria  \
# 0  Loja Matriz           10013                Fogão  Eletrodomésticos
# 1  Loja Matriz           10018              Colchão              Casa
# 2  Loja Matriz           10014            Geladeira  Eletrodomésticos
# 3  Loja Matriz           10001           Smartphone       Eletrônicos
# 4  Loja Matriz           10004  Máquina Lavar Roupa  Eletrodomésticos
#
#   preco_custo valor_unitario  quantidade comissao          dt_venda  \
# ...

# %%
df = pd.read_json('base_vendas.json')

# %%
df.tail()
# Out:
#       matricula_funcionario Nome Funcionario     Cargo codigo_loja  nome_loja  \
# 2995              123457113      Victor Hugo  Vendedor       CL004  Filial ES
# 2996              123457113      Victor Hugo  Vendedor       CL004  Filial ES
# 2997              123457113      Victor Hugo  Vendedor       CL004  Filial ES
# 2998              123457113      Victor Hugo  Vendedor       CL004  Filial ES
# 2999              123457113      Victor Hugo  Vendedor       CL004  Filial ES
#
#       codigo_produto    descricao_produto         Categoria preco_custo  \
# 2995           10006      Aspirador de pó              Casa        88,9
# 2996           10011       Liquidificador           Cozinha        59,9
# 2997           10007            Batedeira           Cozinha        49,9
# 2998           10010  Fritadeira elétrica           Cozinha       187,9
# 2999           10004  Máquina Lavar Roupa  Eletrodomésticos        1099
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3000 entries, 0 to 2999
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   matricula_funcionario  3000 non-null   int64
#  1   Nome Funcionario       3000 non-null   object
#  2   Cargo                  3000 non-null   object
#  3   codigo_loja            3000 non-null   object
#  4   nome_loja              3000 non-null   object
#  5   codigo_produto         3000 non-null   int64
#  6   descricao_produto      3000 non-null   object
#  7   Categoria              3000 non-null   object
#  8   preco_custo            3000 non-null   object
#  9   valor_unitario         3000 non-null   object
#  10  quantidade             3000 non-null   int64
#  11  comissao               159 non-null    object
#  12  dt_venda               3000 non-null   object
#  13  dt_entrega             3000 non-null   object
# dtypes: int64(3), object(11)
# ...

# %%
df_ta = pd.read_table('base_vendas_tab.tsv')
df_ta.head()
# Out:
#    matricula_funcionario Nome Funcionario     Cargo codigo_loja    nome_loja  \
# 0              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 1              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 2              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 3              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 4              123456111       José Maria  Vendedor       CL001  Loja Matriz
#
#    codigo_produto    descricao_produto         Categoria preco_custo  \
# 0           10013                Fogão  Eletrodomésticos       210,9
# 1           10018              Colchão              Casa       109,9
# 2           10014            Geladeira  Eletrodomésticos       699,9
# 3           10001           Smartphone       Eletrônicos       899,9
# 4           10004  Máquina Lavar Roupa  Eletrodomésticos        1099
#
#   valor_unitario  quantidade comissao          dt_venda        dt_entrega
# ...

# %%
# Carregar arquivo '.tsv'

df_t = pd.read_csv('base_vendas_tab.tsv', delimiter='\t')
df_t.tail()
# Out:
#     matricula_funcionario Nome Funcionario     Cargo codigo_loja    nome_loja  \
# 95              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 96              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 97              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 98              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 99              123456111       José Maria  Vendedor       CL001  Loja Matriz
#
#     codigo_produto         descricao_produto    Categoria preco_custo  \
# 95           10017                  Cama Box         Casa      1189,9
# 96           10005                  Notebook  Eletrônicos      2299,9
# 97           10020                Impressora  Eletrônicos       329,9
# 98           10012  Processador de alimentos      Cozinha         110
# 99           10018                   Colchão         Casa       109,9
#
#    valor_unitario  quantidade comissao          dt_venda        dt_entrega
# ...

# %%
import sqlite3

conn = sqlite3.connect('vendas.db')

df_sql = pd.read_sql_query('SELECT* FROM Pedidos', conn)

df_sql
# Out:
#    matricula_funcionario Nome Funcionario     Cargo codigo_loja    nome_loja  \
# 0              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 1              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 2              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 3              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 4              123456111       José Maria  Vendedor       CL001  Loja Matriz
# ..                   ...              ...       ...         ...          ...
# 95             123456111       José Maria  Vendedor       CL001  Loja Matriz
# 96             123456111       José Maria  Vendedor       CL001  Loja Matriz
# 97             123456111       José Maria  Vendedor       CL001  Loja Matriz
# 98             123456111       José Maria  Vendedor       CL001  Loja Matriz
# 99             123456111       José Maria  Vendedor       CL001  Loja Matriz
#
# ...
