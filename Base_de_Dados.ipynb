# %% [markdown]
# <a href="https://colab.research.google.com/github/IagoAlmeida-ias/Python-para-Data-Science/blob/main/Base_de_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('base_rh.csv')

# %%
df
# Out:
#      Funcionario_Deixou_Empresa          Freq_Viagens         Formacao  \
# 0                           Sim       Viaja raramente   Ensino Técnico
# 1                           Não  Viaja frequentemente     Ensino Médio
# 2                           Sim       Viaja raramente   Ensino Técnico
# 3                           Não  Viaja frequentemente         Mestrado
# 4                           Não       Viaja raramente     Ensino Médio
# ...                         ...                   ...              ...
# 1465                        Não  Viaja frequentemente   Ensino Técnico
# 1466                        Não       Viaja raramente     Ensino Médio
# 1467                        Não       Viaja raramente  Ensino Superior
# 1468                        Não  Viaja frequentemente  Ensino Superior
# 1469                        Não       Viaja raramente  Ensino Superior
#
#      Estado_Civil Faz_hora_extras Equilibrio_de_Vida  Idade  Tempo_de_empresa
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Funcionario_Deixou_Empresa  1470 non-null   object
#  1   Freq_Viagens                1470 non-null   object
#  2   Formacao                    1470 non-null   object
#  3   Estado_Civil                1470 non-null   object
#  4   Faz_hora_extras             1470 non-null   object
#  5   Equilibrio_de_Vida          1470 non-null   object
#  6   Idade                       1470 non-null   int64
#  7   Tempo_de_empresa            1470 non-null   int64
# dtypes: int64(2), object(6)
# memory usage: 92.0+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(33)

# %%
colunas = ['funcionario_deixou_empresa', 'freq_viagens', 'formacao',
       'estado_civil', 'faz_hora_extras', 'equilibrio_de_vida', 'idade',
       'tempo_de_empresa']
df.columns = colunas

# %%
df.describe().round(1)
# Out:
#         idade  tempo_de_empresa
# count  1470.0            1470.0
# mean     36.9               7.0
# std       9.1               6.1
# min      18.0               0.0
# 25%      30.0               3.0
# 50%      36.0               5.0
# 75%      43.0               9.0
# max      60.0              40.0

# %%
df.shape
# Out:
# (1470, 8)

# %%
df.describe(include=object).round(1)
# Out:
#        funcionario_deixou_empresa     freq_viagens         formacao  \
# count                        1470             1470             1470
# unique                          2                3                5
# top                           Não  Viaja raramente  Ensino Superior
# freq                         1233             1043              572
#
#        estado_civil faz_hora_extras equilibrio_de_vida
# count          1470            1470               1470
# unique            3               2                  4
# top          Casado             Não          Muito bom
# freq            673            1054                893

# %%
df.head()
# Out:
#   funcionario_deixou_empresa          freq_viagens        formacao  \
# 0                        Sim       Viaja raramente  Ensino Técnico
# 1                        Não  Viaja frequentemente    Ensino Médio
# 2                        Sim       Viaja raramente  Ensino Técnico
# 3                        Não  Viaja frequentemente        Mestrado
# 4                        Não       Viaja raramente    Ensino Médio
#
#   estado_civil faz_hora_extras equilibrio_de_vida  idade  tempo_de_empresa
# 0     Solteiro             Sim               Ruim     41                 6
# 1       Casado             Não          Muito bom     49                10
# 2     Solteiro             Sim          Muito bom     37                 0
# 3       Casado             Sim          Muito bom     33                 8
# 4       Casado             Não          Muito bom     27                 2

# %%
df.tail()
# Out:
#      funcionario_deixou_empresa          freq_viagens         formacao  \
# 1465                        Não  Viaja frequentemente   Ensino Técnico
# 1466                        Não       Viaja raramente     Ensino Médio
# 1467                        Não       Viaja raramente  Ensino Superior
# 1468                        Não  Viaja frequentemente  Ensino Superior
# 1469                        Não       Viaja raramente  Ensino Superior
#
#      estado_civil faz_hora_extras equilibrio_de_vida  idade  tempo_de_empresa
# 1465       Casado             Não          Muito bom     36                 5
# 1466       Casado             Não          Muito bom     39                 7
# 1467       Casado             Sim          Muito bom     27                 6
# 1468       Casado             Não                Bom     49                 9
# 1469       Casado             Não          Excelente     34                 4

# %%
df.isnull().sum()
# Out:
# funcionario_deixou_empresa    0
# freq_viagens                  0
# formacao                      0
# estado_civil                  0
# faz_hora_extras               0
# equilibrio_de_vida            0
# idade                         0
# tempo_de_empresa              0
# dtype: int64
