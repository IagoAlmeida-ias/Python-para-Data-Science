# %% [markdown]
# <a href="https://colab.research.google.com/github/IagoAlmeida-ias/Python-para-Data-Science/blob/main/Desafio_base_Notas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Pacotes de Manipulação de Dados

import numpy as np
import pandas as pd

# Pacates Gráficos

import matplotlib.pyplot as plt
import seaborn as sns

# Pacotes de Modelagem

import statsmodels.api as sm

# %%
# Import da base dados

df =  pd.read_csv('Base_Notas_v1.csv', index_col='id')

# %%
df.head()
# Out:
#     horas_estudo  nota_exame
# id
# 0       5.993428   76.119754
# 1       4.723471   60.929961
# 2       6.295377   81.731317
# 3       8.046060   82.699637
# 4       4.531693   70.662399

# %%
df.tail()
# Out:
#     horas_estudo  nota_exame
# id
# 25      5.221845   68.005282
# 26      2.698013   57.246133
# 27      5.751396   83.669643
# 28      3.798723   84.799914
# 29      4.416613   76.441324

# %%
df.shape
# Out:
# (30, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   horas_estudo  30 non-null     float64
#  1   nota_exame    30 non-null     float64
# dtypes: float64(2)
# memory usage: 720.0 bytes

# %%
df.isnull().sum()
# Out:
# horas_estudo    0
# nota_exame      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe().round()
# Out:
#        horas_estudo  nota_exame
# count          30.0        30.0
# mean            5.0        72.0
# std             2.0         9.0
# min             1.0        54.0
# 25%             4.0        66.0
# 50%             5.0        71.0
# 75%             6.0        78.0
# max             8.0        89.0

# %% [markdown]
# # Complementando - Análise Exploratória dos Dados

# %%
# Gráfico de Dispersão por Horas de estudo

sns.scatterplot(x=df['horas_estudo'],
                y=df['nota_exame']);

# %%
# Correlação linear Persen

df.corr()
# Out:
#               horas_estudo  nota_exame
# horas_estudo      1.000000    0.721178
# nota_exame        0.721178    1.000000

# %%
# Grafico HeatMap

sns.heatmap(df.corr(), cmap='RdBu_r', annot=True, vmin=-1, vmax=1);

# %%
# Variável resposta

y = df['nota_exame']

# Variável explicativa

df['intercepto'] = 1
x = df[ ['intercepto', 'horas_estudo'] ]

# %%
# Ajuste do Modelo

modelo = sm.OLS(y,x)
res = modelo.fit()

# %%
# Resultado do ajuste do modelo

print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             nota_exame   R-squared:                       0.520
# Model:                            OLS   Adj. R-squared:                  0.503
# Method:                 Least Squares   F-statistic:                     30.35
# Date:                Thu, 17 Jul 2025   Prob (F-statistic):           6.92e-06
# Time:                        19:14:12   Log-Likelihood:                -96.553
# No. Observations:                  30   AIC:                             197.1
# Df Residuals:                      28   BIC:                             199.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# intercepto      55.3638      3.197     17.320      0.000      48.816      61.912
# ...
